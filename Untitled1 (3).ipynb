# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
import plotly as py
import plotly.graph_objs as go
import math

# GPU 메모리 제한하기.
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_virtual_device_configuration(gpus[0],
                                                           [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 8 * 1024)])

# %matplotlib inline
warnings.filterwarnings('ignore')
plt.rc('font', family='Malgun Gothic')
print(plt.rcParams['font.family'])
# Out:
# ['Malgun Gothic']

# %% [markdown]
# # 데이터 불러오기

# %%
df = pd.read_csv('monthly_data.csv', encoding = 'euc-kr', index_col = '시점')

df = df.drop('Unnamed: 4', axis = 1)

df
# Out:
#              행정구역별        종류별 출생,사망,혼인,이혼
# 시점
# 1981.01 월       전국    출생아수(명)       88151
# 1981.02 월       전국    출생아수(명)       93556
# 1981.03 월       전국    출생아수(명)       70421
# 1981.04 월       전국    출생아수(명)       66093
# 1981.05 월       전국    출생아수(명)       68940
# ...            ...        ...         ...
# 2022.11 월  제주특별자치도  조이혼율(천명당)         2.3
# 2022.12 월  제주특별자치도  조이혼율(천명당)         2.2
# 2023.01 월  제주특별자치도  조이혼율(천명당)         1.7
# 2023.02 월  제주특별자치도  조이혼율(천명당)         2.2
# 2023.03 월  제주특별자치도  조이혼율(천명당)         2.6
#
# [65902 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['행정구역별', '종류별', '출생,사망,혼인,이혼'], dtype='object')

# %% [markdown]
# # 사용할 데이터만 뽑아내기(전국 데이터)

# %%
is_all = df['행정구역별'] == '전국'

allData = df[is_all]

allData
# Out:
#           행정구역별        종류별 출생,사망,혼인,이혼
# 시점
# 1981.01 월    전국    출생아수(명)       88151
# 1981.02 월    전국    출생아수(명)       93556
# 1981.03 월    전국    출생아수(명)       70421
# 1981.04 월    전국    출생아수(명)       66093
# 1981.05 월    전국    출생아수(명)       68940
# ...         ...        ...         ...
# 2022.11 월    전국  조이혼율(천명당)           2
# 2022.12 월    전국  조이혼율(천명당)         1.8
# 2023.01 월    전국  조이혼율(천명당)         1.7
# 2023.02 월    전국  조이혼율(천명당)         1.8
# 2023.03 월    전국  조이혼율(천명당)         1.9
#
# [3906 rows x 3 columns]

# %%
columns_names = df['종류별'].unique()

columns_names
# Out:
# array(['출생아수(명)', '조출생률(천명당)', '사망자수(명)', '조사망률(천명당)', '자연증가건수(명)',
#        '자연증가율(천명당)', '혼인건수(건)', '조혼인율(천명당)', '이혼건수(건)', '조이혼율(천명당)'],
#       dtype=object)

# %% [markdown]
# # 전국 데이터를 필요한 형태로 가공하기

# %%
new_df = pd.DataFrame()

for column in columns_names:
    tmp = allData['종류별'] == column
    newDf = allData[tmp]
    newDf = newDf.rename(columns = {'출생,사망,혼인,이혼' : column})
    newDf = newDf.drop('종류별', axis = 1)
    new_df[column] = newDf[column]

new_df.index = pd.to_datetime(new_df.index, format='%Y.%m 월')

new_df = new_df.apply(pd.to_numeric, errors='coerce')
new_df
# Out:
#             출생아수(명)  조출생률(천명당)  사망자수(명)  조사망률(천명당)  자연증가건수(명)  자연증가율(천명당)  \
# 시점
# 1981-01-01    88151        NaN      NaN        NaN        NaN         NaN
# 1981-02-01    93556        NaN      NaN        NaN        NaN         NaN
# 1981-03-01    70421        NaN      NaN        NaN        NaN         NaN
# 1981-04-01    66093        NaN      NaN        NaN        NaN         NaN
# 1981-05-01    68940        NaN      NaN        NaN        NaN         NaN
# ...             ...        ...      ...        ...        ...         ...
# 2022-11-01    18940        4.5  30138.0        7.2   -11198.0        -2.7
# 2022-12-01    16803        3.9  33360.0        7.7   -16557.0        -3.8
# 2023-01-01    23179        5.3  32703.0        7.5    -9524.0        -2.2
# 2023-02-01    19939        5.1  27390.0        7.0    -7452.0        -1.9
# 2023-03-01    21138        4.9  28922.0        6.7    -7784.0        -1.8
#
#             혼인건수(건)  조혼인율(천명당)  이혼건수(건)  조이혼율(천명당)
# 시점
# 1981-01-01    49285        NaN     1827        NaN
# 1981-02-01    34481        NaN     1687        NaN
# 1981-03-01    47843        NaN     2094        NaN
# 1981-04-01    35956        NaN     2189        NaN
# 1981-05-01    35769        NaN     2059        NaN
# ...             ...        ...      ...        ...
# 2022-11-01    17455        4.1     8498        2.0
# 2022-12-01    19883        4.6     7821        1.8
# 2023-01-01    17926        4.1     7251        1.7
# 2023-02-01    17846        4.5     7228        1.8
# 2023-03-01    18192        4.2     8255        1.9
#
# [507 rows x 10 columns]

# %% [markdown]
# # 결측값이 없는 년도 부터 데이터 시작

# %%
new_df = new_df[24:]

new_df
# Out:
#             출생아수(명)  조출생률(천명당)  사망자수(명)  조사망률(천명당)  자연증가건수(명)  자연증가율(천명당)  \
# 시점
# 1983-01-01    86723        NaN  23147.0        NaN    63576.0         NaN
# 1983-02-01    89422        NaN  20099.0        NaN    69323.0         NaN
# 1983-03-01    61169        NaN  22632.0        NaN    38537.0         NaN
# 1983-04-01    56581        NaN  21767.0        NaN    34814.0         NaN
# 1983-05-01    57580        NaN  18412.0        NaN    39168.0         NaN
# ...             ...        ...      ...        ...        ...         ...
# 2022-11-01    18940        4.5  30138.0        7.2   -11198.0        -2.7
# 2022-12-01    16803        3.9  33360.0        7.7   -16557.0        -3.8
# 2023-01-01    23179        5.3  32703.0        7.5    -9524.0        -2.2
# 2023-02-01    19939        5.1  27390.0        7.0    -7452.0        -1.9
# 2023-03-01    21138        4.9  28922.0        6.7    -7784.0        -1.8
#
#             혼인건수(건)  조혼인율(천명당)  이혼건수(건)  조이혼율(천명당)
# 시점
# 1983-01-01    37763        NaN     2178        NaN
# 1983-02-01    35454        NaN     1970        NaN
# 1983-03-01    42980        NaN     2431        NaN
# 1983-04-01    36991        NaN     2309        NaN
# 1983-05-01    37849        NaN     2318        NaN
# ...             ...        ...      ...        ...
# 2022-11-01    17455        4.1     8498        2.0
# 2022-12-01    19883        4.6     7821        1.8
# 2023-01-01    17926        4.1     7251        1.7
# 2023-02-01    17846        4.5     7228        1.8
# 2023-03-01    18192        4.2     8255        1.9
#
# [483 rows x 10 columns]

# %% [markdown]
# # 출생아수(명) 예측에 불필요한 컬럼 삭제하기

# %%
columns = list(new_df.columns)
garbage_data = ['조출생률(천명당)', '조사망률(천명당)', '자연증가율(천명당)', '조혼인율(천명당)', '조이혼율(천명당)']

for column in garbage_data:
    columns.remove(column)

print(columns)
# Out:
# ['출생아수(명)', '사망자수(명)', '자연증가건수(명)', '혼인건수(건)', '이혼건수(건)']

# %% [markdown]
# # 결측값(Nan) 보간하기. 뒤에서 부터 데이터를 읽으면서 비어 있는 값들을 보간한다.

# %%
# 결측값 보간하기. 뒤에서 부터 데이터를 읽으면서 비어있는 값을 보간함.

interpolated_df = pd.DataFrame()
for column in columns:
    if(new_df[column].isnull().sum() != 0):
        ts = pd.Series(new_df[column], index = new_df.index)
        ts_intp_linear = ts.interpolate(method = 'time', limit_direction = 'backward')
        interpolated_df[column] = ts_intp_linear
    else:
        interpolated_df[column] = new_df[column]
        
interpolated_df = interpolated_df.apply(lambda x: x.astype(int))

interpolated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 483 entries, 1983-01-01 to 2023-03-01
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   출생아수(명)    483 non-null    int32
#  1   사망자수(명)    483 non-null    int32
#  2   자연증가건수(명)  483 non-null    int32
#  3   혼인건수(건)    483 non-null    int32
#  4   이혼건수(건)    483 non-null    int32
# dtypes: int32(5)
# memory usage: 13.2 KB

# %% [markdown]
# # 데이터 증강하기

# %%
# 기존의 데이터가 학습하기에 너무 부족하다.
# 데이터의 시작 부터 끝 까지 데이터 중간에 결측값을 하나씩 집어 넣는다.
# 그 결측값들을 시간 순서에 따라서 보간한다.

start_date = pd.to_datetime('1982-12-01')
end_date = pd.to_datetime('2023-02-01')

dates = pd.date_range(start = start_date, end = end_date, freq = 'M')
dates = dates + pd.DateOffset(months=1) - pd.DateOffset(day = 15)

empty_df = pd.DataFrame(index = dates, columns = columns)
empty_df = empty_df.fillna(0)
empty_df = empty_df.astype(int)
empty_df = empty_df.replace(0, np.nan)
empty_df = pd.concat([interpolated_df, empty_df])

# %%
empty_df = empty_df.sort_index()

empty_df
# Out:
#             출생아수(명)  사망자수(명)  자연증가건수(명)  혼인건수(건)  이혼건수(건)
# 1983-01-01  86723.0  23147.0    63576.0  37763.0   2178.0
# 1983-01-15      NaN      NaN        NaN      NaN      NaN
# 1983-02-01  89422.0  20099.0    69323.0  35454.0   1970.0
# 1983-02-15      NaN      NaN        NaN      NaN      NaN
# 1983-03-01  61169.0  22632.0    38537.0  42980.0   2431.0
# ...             ...      ...        ...      ...      ...
# 2023-01-01  23179.0  32703.0    -9524.0  17926.0   7251.0
# 2023-01-15      NaN      NaN        NaN      NaN      NaN
# 2023-02-01  19939.0  27390.0    -7452.0  17846.0   7228.0
# 2023-02-15      NaN      NaN        NaN      NaN      NaN
# 2023-03-01  21138.0  28922.0    -7784.0  18192.0   8255.0
#
# [965 rows x 5 columns]

# %%
empty_df.index.name = 'time'
interpolated_df = empty_df.interpolate(mathod = 'time')
interpolated_df = interpolated_df.astype(int)
max_values = interpolated_df.max()
max_value = max_values['출생아수(명)']
min_values = interpolated_df.min()
min_value = min_values['출생아수(명)']
print(interpolated_df)
# Out:
#             출생아수(명)  사망자수(명)  자연증가건수(명)  혼인건수(건)  이혼건수(건)
# time
# 1983-01-01    86723    23147      63576    37763     2178
# 1983-01-15    88072    21623      66449    36608     2074
# 1983-02-01    89422    20099      69323    35454     1970
# 1983-02-15    75295    21365      53930    39217     2200
# 1983-03-01    61169    22632      38537    42980     2431
# ...             ...      ...        ...      ...      ...
# 2023-01-01    23179    32703      -9524    17926     7251
# 2023-01-15    21559    30046      -8488    17886     7239
# 2023-02-01    19939    27390      -7452    17846     7228
# 2023-02-15    20538    28156      -7618    18019     7741
# 2023-03-01    21138    28922      -7784    18192     8255
#
# [965 rows x 5 columns]

# %% [markdown]
# # 데이터 스케일링

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

scaler = MinMaxScaler()
scale_cols = columns
scaled = scaler.fit_transform(interpolated_df[scale_cols])
scaled
# Out:
# array([[0.96283342, 0.21789827, 0.93679893, 0.65336197, 0.01535395],
#        [0.98140982, 0.162367  , 0.96839396, 0.62195818, 0.00767698],
#        [1.        , 0.10683574, 1.        , 0.59058158, 0.        ],
#        ...,
#        [0.04318429, 0.37250401, 0.15568777, 0.11183012, 0.38813021],
#        [0.05143282, 0.40041539, 0.15386223, 0.11653389, 0.42599838],
#        [0.05969512, 0.42832677, 0.15203669, 0.12123766, 0.46394036]])

# %%
df = pd.DataFrame(scaled, columns = scale_cols, index = interpolated_df.index)
df
# Out:
#              출생아수(명)   사망자수(명)  자연증가건수(명)   혼인건수(건)   이혼건수(건)
# time
# 1983-01-01  0.962833  0.217898   0.936799  0.653362  0.015354
# 1983-01-15  0.981410  0.162367   0.968394  0.621958  0.007677
# 1983-02-01  1.000000  0.106836   1.000000  0.590582  0.000000
# 1983-02-15  0.805464  0.152966   0.830720  0.692895  0.016978
# 1983-03-01  0.610942  0.199133   0.661439  0.795209  0.034030
# ...              ...       ...        ...       ...       ...
# 2023-01-01  0.087801  0.566098   0.132902  0.114005  0.389828
# 2023-01-15  0.065493  0.469283   0.144295  0.112918  0.388942
# 2023-02-01  0.043184  0.372504   0.155688  0.111830  0.388130
# 2023-02-15  0.051433  0.400415   0.153862  0.116534  0.425998
# 2023-03-01  0.059695  0.428327   0.152037  0.121238  0.463940
#
# [965 rows x 5 columns]

# %%
born = df['출생아수(명)'].values.tolist()
born
# Out:
# [0.9628334182514219,
#  0.9814098238752943,
#  1.0,
#  0.8054641347305801,
#  0.6109420399619935,
#  0.579352511050827,
#  0.5477629821396605,
#  0.554634462055385,
#  0.5615197124719427,
#  0.5435629793855603,
#  0.525606246299178,
#  0.5440587174155525,
#  0.5625111885319269,
#  0.5691072584309892,
#  0.5757170988308845,
#  0.5799997245899834,
#  0.5842823503490823,
#  0.6132830251036231,
#  0.642297470358997,
#  0.6397086162023713,
#  0.6371197620457456,
#  0.6207741775568377,
#  0.60442859306793,
#  0.7281565430534709,
#  0.851898263539845,
#  0.9062779713298174,
#  0.9606576791197897,
#  0.7147027637395172,
#  0.46876161886007794,
#  0.45584488907861587,
#  0.44294192979798674,
#  0.43730979495724265,
#  0.43167766011649844,
#  0.4216114240074912,
#  0.411558958399317,
#  0.4388245500488853,
#  0.4661039121992867,
#  0.4737052286591663,
#  0.4813203156198791,
#  0.48857736955893094,
#  0.49584819399881574,
#  0.5243118192208651,
#  0.5527892149437476,
#  0.525730180806676,
#  0.4986849171704375,
#  0.4760186727991297,
#  0.45336619892865504,
#  0.613035156088627,
#  0.7727178837494321,
#  0.7890634682383398,
#  0.8054090527272478,
#  0.6205263085418417,
#  0.43565733485726876,
#  0.41449207507677055,
#  0.39332681529627234,
#  0.4072350211377188,
#  0.4211432269791653,
#  0.1408722235227695,
#  0.1432682906677316,
#  0.14566435781269366,
#  0.1366033682645038,
#  0.12755614921714703,
#  0.13036533138710255,
#  0.13317451355705806,
#  0.12509122956801938,
#  0.11702171607981382,
#  0.09957449152425674,
#  0.08212726696869965,
#  0.1337941860945483,
#  0.18546110522039688,
#  0.1540505928200609,
#  0.12265385092055797,
#  0.13186631597791215,
#  0.1410925515360994,
#  0.13457910464203582,
#  0.12807942824880542,
#  0.12252991641305994,
#  0.11699417507814758,
#  0.10798826753329022,
#  0.09899613048926592,
#  0.10746498850163183,
#  0.11593384651399774,
#  0.11006761315909058,
#  0.1042151503050166,
#  0.10227350968754734,
#  0.1003456395709112,
#  0.11082499070491192,
#  0.12131811233974582,
#  0.10833253005411808,
#  0.09534694776849034,
#  0.07813382172709621,
#  0.0609344661865352,
#  0.09823875294344458,
#  0.13554303970035392,
#  0.10877318608077774,
#  0.08201710296203474,
#  0.09186301105771216,
#  0.10172268965422271,
#  0.09558104628265329,
#  0.089453173411917,
#  0.08634104022363293,
#  0.08322890703534891,
#  0.07820267423126182,
#  0.07317644142717472,
#  0.07924923229457859,
#  0.0853220231619824,
#  0.08120464341288092,
#  0.07710103416461256,
#  0.08464726862115973,
#  0.09220727357854008,
#  0.08108070890538288,
#  0.06996791473305886,
#  0.057367906470758345,
#  0.044767898208457835,
#  0.041917404536002956,
#  0.03908068136438125,
#  0.07524201655214202,
#  0.11141712224073591,
#  0.08671284374612703,
#  0.06200856525151821,
#  0.08003415084206611,
#  0.09807350693344719,
#  0.0896597309244137,
#  0.08124595491538028,
#  0.0758616890896322,
#  0.07049119376471724,
#  0.06761315909059612,
#  0.06473512441647505,
#  0.07065643977471459,
#  0.07657775513295417,
#  0.07601316459879648,
#  0.07544857406463873,
#  0.07284594940717992,
#  0.07025709525055429,
#  0.062297745769013646,
#  0.054338396287473,
#  0.04800396590423994,
#  0.041669535521006884,
#  0.023423621917129156,
#  0.005177708313251345,
#  0.056720692931601924,
#  0.10826367754995248,
#  0.08099808590038421,
#  0.05373249425081589,
#  0.06954102920723226,
#  0.08534956416364864,
#  0.07270824439884876,
#  0.060066924634048946,
#  0.052438067172503044,
#  0.0448092097109572,
#  0.03690494223274898,
#  0.029014445255373944,
#  0.03989314091353502,
#  0.050771836571696094,
#  0.059640039108222354,
#  0.06850824164474861,
#  0.0693620126964018,
#  0.07022955424888805,
#  0.06134758121152867,
#  0.05247937867500241,
#  0.04095346947768491,
#  0.029427560280367415,
#  0.014706894889767147,
#  0.0,
#  0.043900356655971584,
#  0.08780071331194317,
#  0.06549250196229639,
#  0.04318429061264961,
#  0.05143282061168564,
#  0.05969512111155484]

# %%
window_size = 5
x = []
y = []

for i in range(len(born) - window_size):
    x.append([born[i+j] for j in range(window_size)])
    y.append(born[window_size + i])

# %%
x = np.asarray(x)
y = np.asarray(y)
print(len(y))
# Out:
# 960

# %% [markdown]
# # 학습 데이터와 검증 데이터 분리

# %%
train_test_split = 200

x_train = x[:train_test_split, :]
y_train = y[:train_test_split]

x_test = x[train_test_split:, :]
y_test = y[train_test_split : ]

# %% [markdown]
# # LSTM 모델 생성

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda, Dropout
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model = Sequential([
    LSTM(128, input_shape = (x_train.shape[1], 1, )),
    Dropout(0.2),
    Dense(64, activation = 'relu'),
    Dense(1, activation = 'relu')
])

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

# 10번 epoch 동안 loss 개선이 없다면 학습 종료
earlystopping = EarlyStopping(monitor = 'loss', patience = 20)

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 128)               66560
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 74,881
# Trainable params: 74,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs = 200, callbacks = [earlystopping], batch_size = 2)
history
# Out:
# Epoch 1/200
# 100/100 [==============================] - 2s 6ms/step - loss: 0.0270 - mse: 0.0270
# Epoch 2/200
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0137 - mse: 0.0137
# Epoch 3/200
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0123 - mse: 0.0123
# Epoch 4/200
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0118 - mse: 0.0118
# Epoch 5/200
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0086 - mse: 0.0086
# Epoch 6/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0091 - mse: 0.0091
# Epoch 7/200
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0076 - mse: 0.0076
# Epoch 8/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0072 - mse: 0.0072
# Epoch 9/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0069 - mse: 0.0069
# Epoch 10/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0062 - mse: 0.0062
# Epoch 11/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0059 - mse: 0.0059
# Epoch 12/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0061 - mse: 0.0061
# Epoch 13/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0052 - mse: 0.0052
# Epoch 14/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0056 - mse: 0.0056
# Epoch 15/200
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0043 - mse: 0.0043
# Epoch 16/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0046 - mse: 0.0046
# Epoch 17/200
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0048 - mse: 0.0048
# Epoch 18/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0041 - mse: 0.0041
# Epoch 19/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0049 - mse: 0.0049
# Epoch 20/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0041 - mse: 0.0041
# Epoch 21/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 22/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0040 - mse: 0.0040
# Epoch 23/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0042 - mse: 0.0042
# Epoch 24/200
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0044 - mse: 0.0044
# Epoch 25/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 26/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 27/200
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 28/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 29/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 30/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 31/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0043 - mse: 0.0043
# Epoch 32/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 33/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 34/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 35/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 36/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 37/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 38/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 39/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 40/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0039 - mse: 0.0039
# Epoch 41/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 42/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 43/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 44/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 45/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0037 - mse: 0.0037
# Epoch 46/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 47/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0034 - mse: 0.0034
# Epoch 48/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 49/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 50/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0035 - mse: 0.0035
# Epoch 51/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 52/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0032 - mse: 0.0032
# Epoch 53/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 54/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0036 - mse: 0.0036
# Epoch 55/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0029 - mse: 0.0029
# Epoch 56/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 57/200
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0029 - mse: 0.0029

# %%
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

index_list = list(interpolated_df.index)
train_index = index_list[window_size : train_test_split + window_size]
test_index = index_list[train_test_split + window_size:]

plt.figure(figsize = (16, 10))
plt.plot(index_list, born)

split_pt = train_test_split + window_size
plt.plot(train_index, train_predict[:,0], color = 'g')
plt.plot(test_index, test_predict[:,0], color = 'r')
# Out:
# 7/7 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step

# %%
plt.figure(figsize = (16, 9))
plt.plot(born)
plt.plot(np.arange(train_test_split + window_size, len(y) + window_size), test_predict[:, 0], color = 'r')

# %%
test_predict_df = pd.DataFrame(test_predict[:, 0], columns=['예상 출생아수'])
test_predict_df
# Out:
#       예상 출생아수
# 0    0.541517
# 1    0.543582
# 2    0.547177
# 3    0.564893
# 4    0.581697
# ..        ...
# 755  0.088717
# 756  0.124280
# 757  0.087125
# 758  0.073770
# 759  0.083703
#
# [760 rows x 1 columns]

# %%
def original_value(converted_value):
    return math.floor(converted_value * (max_value - min_value) + min_value)

original_train_value = []
original_test_value = []
for i in train_predict:
    original_train_value.append(original_value(i[0]))
    
for i in test_predict:
    original_test_value.append(original_value(i[0]))

# %%
train_df = pd.DataFrame(original_train_value, columns=['출생아수(명)'], index = train_index)
test_df = pd.DataFrame(original_test_value, columns=['출생아수(명)'], index = test_index)
print("실제 데이터 ------------------------")
print(interpolated_df.tail())
print("예측 데이터 ------------------------")
print(test_df.tail())
# Out:
# 실제 데이터 ------------------------
#             출생아수(명)  사망자수(명)  자연증가건수(명)  혼인건수(건)  이혼건수(건)
# time
# 2023-01-01    23179    32703      -9524    17926     7251
# 2023-01-15    21559    30046      -8488    17886     7239
# 2023-02-01    19939    27390      -7452    17846     7228
# 2023-02-15    20538    28156      -7618    18019     7741
# 2023-03-01    21138    28922      -7784    18192     8255
# 예측 데이터 ------------------------
#             출생아수(명)
# 2023-01-01    23245
# 2023-01-15    25828
# 2023-02-01    23129
# 2023-02-15    22160
# 2023-03-01    22881
